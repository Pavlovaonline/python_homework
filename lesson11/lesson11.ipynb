# %%
from sympy import*
from sympy.plotting import plot
init_printing()

# %%
x = Symbol('x')
y = -12*x**4
solve(y)
# Out:
# [0]

# %%
from sympy import*
from sympy.plotting import plot
init_printing()

# %%
x = Symbol('x')
y = sin(cos(x))
solve(y)
# Out:
# ⎡π  3⋅π                        ⎤
# ⎢─, ───, 2⋅π - acos(π), acos(π)⎥
# ⎣2   2                         ⎦

# %%
x = Symbol('x')
y = -18*x**3+5*x**2+10*x-30
solve(y)
# Out:
# ⎡                                                                  ___________
# ⎢                                                 ⎛  1   √3⋅ⅈ⎞    ╱ 5⋅√218931
# ⎢                                                 ⎜- ─ - ────⎟⋅3 ╱  ─────────
# ⎢5                       565                      ⎝  2    2  ⎠ ╲╱      108
# ⎢── - ───────────────────────────────────────── - ────────────────────────────
# ⎢54                        ____________________                     3
# ⎢         ⎛  1   √3⋅ⅈ⎞    ╱ 5⋅√218931   127045
# ⎢     972⋅⎜- ─ - ────⎟⋅3 ╱  ───────── + ──────
# ⎣         ⎝  2    2  ⎠ ╲╱      108       5832
#
# _________                        ____________________
#   127045        ⎛  1   √3⋅ⅈ⎞    ╱ 5⋅√218931   127045
# + ──────        ⎜- ─ + ────⎟⋅3 ╱  ───────── + ──────
#    5832    5    ⎝  2    2  ⎠ ╲╱      108       5832                        565
# ─────────, ── - ───────────────────────────────────── - ──────────────────────
#            54                     3                                          _
#                                                             ⎛  1   √3⋅ⅈ⎞    ╱
#                                                         972⋅⎜- ─ + ────⎟⋅3 ╱
#                                                             ⎝  2    2  ⎠ ╲╱
#
#                            ____________________
#                           ╱ 5⋅√218931   127045
#                        3 ╱  ───────── + ──────
#                        ╲╱      108       5832                 565
# ───────────────────, - ──────────────────────── - ────────────────────────────
# ___________________               3                       ____________________
# 5⋅√218931   127045                                       ╱ 5⋅√218931   127045
# ───────── + ──────                                972⋅3 ╱  ───────── + ──────
#    108       5832                                     ╲╱      108       5832
#
#      ⎤
#      ⎥
#      ⎥
#    5 ⎥
#  + ──⎥
#    54⎥
#      ⎥
#      ⎥
#      ⎦

# %%
x = Symbol('x')
y = -12*x**4*sin(cos(x))-18*x**3+5*x**2 + 10*x-30
plot(y)
print(y)
# Out:
# -12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30
